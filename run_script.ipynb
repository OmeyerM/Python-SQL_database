# %% [markdown]
# #### Wywołanie skryptu
# ##### Tworzy bazę danych sales_data, tworzy tabelę orders i wypełnia ją wartościami z pliku csv

# %%
# %run "skrypt_final.py"

# %% [markdown]
# #### Przykładowe zapytania

# %%
# %load_ext sql
import configparser
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# Łączenie z bazą danych sales_data
config = configparser.ConfigParser()
config.read('private.cfg')
DB_NAME_DEFAULT = config.get('SQL', 'DB_NAME_DEFAULT')
DB_USER = config.get('SQL', 'DB_USER')
DB_PASSWORD = config.get('SQL', 'DB_PASSWORD')

conn_string = "postgresql://{}:{}@127.0.0.1/sales_data".format(DB_USER, DB_PASSWORD)
# %sql $conn_string

# %%
# Zliczenie wierszy w tabeli (spr czy pobiera dane)
# %sql SELECT COUNT(*) FROM orders;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sales_data
# 1 rows affected.
# [(307,)]

# %%
# Wyświetlenie wszystkich rekordów z tabeli orders
# %sql SELECT * FROM orders;
# Out:
#  * postgresql://postgres:***@127.0.0.1/sales_data
# 307 rows affected.
# [(10107, 30, Decimal('95.7'), 2, Decimal('2871.0'), datetime.date(2003, 2, 24), 'Shipped', 1, 2, 2003, 'Motorcycles', 95, 'S10_1678', 'Land of Toys Inc.', '2125557818', '897 Long Airport Avenue', 'NaN', 'NYC', 'NY', '10022', 'USA', 'NaN', 'Yu', 'Kwai', 'Small'),
#  (10121, 34, Decimal('81.35'), 5, Decimal('2765.9'), datetime.date(2003, 5, 7), 'Shipped', 2, 5, 2003, 'Motorcycles', 95, 'S10_1678', 'Reims Collectables', '26.47.1555', "59 rue de l'Abbaye", 'NaN', 'Reims', 'NaN', '51100', 'France', 'EMEA', 'Henriot', 'Paul', 'Small'),
#  (10134, 41, Decimal('94.74'), 2, Decimal('3884.34'), datetime.date(2003, 7, 1), 'Shipped', 3, 7, 2003, 'Motorcycles', 95, 'S10_1678', 'Lyon Souveniers', '+33 1 46 62 7555', '27 rue du Colonel Pierre Avia', 'NaN', 'Paris', 'NaN', '75508', 'France', 'EMEA', 'Da Cunha', 'Daniel', 'Medium'),
# ...

# %%
# Wybór tylko tych rekordów, które mają status inny niż 'Shipped' - wysłane
# %sql SELECT * FROM orders WHERE NOT status = 'Shipped';
# Out:
#  * postgresql://postgres:***@127.0.0.1/sales_data
# 21 rows affected.
# [(10417, 66, Decimal('100.0'), 2, Decimal('7516.08'), datetime.date(2005, 5, 13), 'Disputed', 2, 5, 2005, 'Motorcycles', 95, 'S10_1678', 'Euro Shopping Channel', '(91) 555 94 44', 'C/ Moralzarzal, 86', 'NaN', 'Madrid', 'NaN', '28034', 'Spain', 'EMEA', 'Freyre', 'Diego', 'Large'),
#  (10424, 50, Decimal('100.0'), 6, Decimal('12001.0'), datetime.date(2005, 5, 31), 'In Process', 2, 5, 2005, 'Classic Cars', 214, 'S10_1949', 'Euro Shopping Channel', '(91) 555 94 44', 'C/ Moralzarzal, 86', 'NaN', 'Madrid', 'NaN', '28034', 'Spain', 'EMEA', 'Freyre', 'Diego', 'Large'),
#  (10167, 44, Decimal('100.0'), 9, Decimal('5924.16'), datetime.date(2003, 10, 23), 'Cancelled', 4, 10, 2003, 'Classic Cars', 136, 'S10_4757', 'Scandinavian Gift Ideas', '0695-34 6555', '?kergatan 24', 'NaN', 'Boras', 'NaN', 'S-844 67', 'Sweden', 'EMEA', 'Larsson', 'Maria', 'Medium'),
# ...
